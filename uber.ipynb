# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## Data Cleaning and Analysis

# %%
df = pd.read_csv('uberdataset.csv')
df.head()
# Out:
#          START_DATE          END_DATE  CATEGORY        START             STOP  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
df.nunique()
# Out:
# START_DATE    1155
# END_DATE      1154
# CATEGORY         2
# START          177
# STOP           188
# MILES          257
# PURPOSE         10
# dtype: int64

# %%
df.isnull().sum()
# Out:
# START_DATE      0
# END_DATE        1
# CATEGORY        1
# START           1
# STOP            1
# MILES           0
# PURPOSE       503
# dtype: int64

# %%
df.shape
# Out:
# (1156, 7)

# %%
df.drop(columns=['PURPOSE'], inplace=True)

# %%
df.isnull().sum()
# Out:
# START_DATE    0
# END_DATE      1
# CATEGORY      1
# START         1
# STOP          1
# MILES         0
# dtype: int64

# %%
x = df.describe()
print(x)
# Out:
#               MILES
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1156 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
# dtypes: float64(1), object(5)
# memory usage: 54.3+ KB

# %% [markdown]
# ## Visualization

# %%
px.bar(x,title='Bar chart of index')

# %%
px.pie(df,names='CATEGORY',title='Uber Category')

# %%
px.line(df,x='START_DATE',y='MILES',color='CATEGORY',title='Miles at start date')

# %%
px.line(df,x='END_DATE',y='MILES',color='CATEGORY',title='Miles at end date')

# %%
px.violin(df,x='START',y='MILES',color='CATEGORY',title='Miles at starting point')

# %%
px.violin(df,x='STOP',y='MILES',color='CATEGORY',title='Miles at stopping point')

# %%
px.area(df,y='MILES',x='START',color='CATEGORY',title='Miles at starting point')

# %%
px.area(df,y='MILES',x='STOP',color='CATEGORY',title='Miles at stopping point')
